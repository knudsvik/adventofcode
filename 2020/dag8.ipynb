# %%
import operator

# %%
ops = { "+": operator.add, "-": operator.sub }

# %%
data = open('dag8_test.txt', 'r')

# %%
data = open('dag8.txt', 'r')

# %%
code = data.readlines()

# %%
data.close()

# %% [markdown]
# acc increases or decreases a single global value called the accumulator by the value given in the argument. For example, acc +7 would increase the accumulator by 7. The accumulator starts at 0. After an acc instruction, the instruction immediately below it is executed next.

# %% [markdown]
# jmp jumps to a new instruction relative to itself. The next instruction to execute is found using the argument as an offset from the jmp instruction; for example, jmp +2 would skip the next instruction, jmp +1 would continue to the instruction immediately below it, and jmp -20 would cause the instruction 20 lines above to be executed next.

# %% [markdown]
# nop stands for No OPeration - it does nothing. The instruction immediately below it is executed next.

# %%
line = 0
accumulator = 0
iteration = 0
runned_lines = []

while line not in runned_lines:
    instruction = code[line].split()[0]
    arg = code[line].split()[1]
    
    if instruction == 'nop':
        next_line = line + 1
    elif instruction == 'acc':
        next_line = line + 1
        accumulator += ops[arg[0]](0, int(arg[1:]))
    elif instruction == 'jmp':
        next_line = line + ops[arg[0]](0, int(arg[1:]))
        
    previous_line = line
    line = next_line
    runned_lines.append(previous_line)
    
print('accumulator at:', accumulator)
# Out:
# accumulator at: 5

# %%
line = 0
accumulator = 0
iteration = 0
runned_lines = []
line_nop = -1
tried_nops = []

while line not in runned_lines:
    print('line:', line)
    instruction = code[line].split()[0]
    arg = code[line].split()[1]
        
    if instruction == 'nop' and override_nop != True:
        next_line = line + 1
    if instruction == 'acc':
        next_line = line + 1
        accumulator += ops[arg[0]](0, int(arg[1:]))
    if instruction == 'jmp' or override_nop == True:
        next_line = line + ops[arg[0]](0, int(arg[1:]))
        
    previous_line = line
    line = next_line

    if next_line in runned_lines or next_line == previous_line:
        print('Discovered infinite loop. Trying to change some nop to jmp')
        line_nop += 1
        override_nop = False
        while override_nop == False:
            for line in range(line_nop, len(code)):
                instruction = code[line].split()[0]
                print('instruction:', instruction)
                if instruction == 'nop' and line not in tried_nops:
                    print('kom inn her')
                    override_nop = True
                    tried_nops.append(line_nop)
            
        runned_lines = [] # resetter
        line = 0
    else:
        runned_lines.append(previous_line)
    
print('accumulator at:', accumulator)
print('tried_nops:', tried_nops)
# Out:
# line: 0
# Discovered infinite loop. Trying to change some nop to jmp
# instruction: nop
# kom inn her
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# line: 0
# Discovered infinite loop. Trying to change some nop to jmp
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# instruction: acc
# instruction: jmp
# instruction: acc
# ...

# %%
tried_nops
# Out:
# [0]

# %%
0 in tried_nops
# Out:
# True

# %%
for instruction in code[line].split():
    print(instruction)
# Out:
# acc
# +3

# %%
line_no = 0
for line in code:
    instruction = code[line_no].split()[0]
    if instruction == 'nop':
        override_nop = True
        line_nop = line
    line_no += 1
# Out:
# nop
# acc
# jmp
# acc
# jmp
# acc
# acc
# jmp
# acc

# %%
range(line_nop, len(code))
# Out:
# range(0, 9)

# %%
for i in range(line_nop, len(code)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
